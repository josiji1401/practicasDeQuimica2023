# %% [markdown]
# <a href="https://colab.research.google.com/github/josiji1401/practicasDeQuimica2023/blob/main/PC_2_Quimica_UNMSM_listo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $$\Large \textit{UNMSM | Química}$$
# $$\large \textbf{PC Nº2 | Materia y clasificación}$$
#
# _Profesor: Jesus Alvarado Huayhuaz_

# %% [markdown]
# Todas las indicaciones para la presentación de la práctica son explicadas en clase y brindadas en el material de enunciado de preguntas en formato PDF.

# %% [markdown]
# ## Pregunta 1: DataFrames y listas en python (4 puntos)

# %% [markdown]
# Usando PeriodicTable, crea una tabla con 20 elementos químicos y en las columnas considera: nombre, simbolo, masa_atomica, numero_atomico	y valencias. Puedes ayudarte del siguiente [material](https://github.com/inefable12/UNMSM_quimica_2023/blob/main/Python_para_quimica_2023.ipynb).

# %%
# !pip install rdkit
from rdkit import Chem

PeriodicTable = Chem.GetPeriodicTable()

help(PeriodicTable)
# Podemos generar una lista de elementos

element_symbols = []

for i in range(1,21):
  element_symbols.append(PeriodicTable.GetElementSymbol(i))
element_symbols
['H', 'He', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Ne']

numero_atomico = [PeriodicTable.GetAtomicNumber(x) for x in element_symbols]
masa_atomica = [PeriodicTable.GetAtomicWeight(x) for x in element_symbols]
nombre_del_elemento = [PeriodicTable.GetElementName(x) for x in range(1,21)]
valencias = [PeriodicTable.GetValenceList(x) for x in range(1,21)]

import pandas as pd

data = {'nombre': nombre_del_elemento, 'simbolo': element_symbols,
        'masa_atomica': masa_atomica, 'numero_atomico': numero_atomico,
        'valencias': valencias}
df = pd.DataFrame(data)
df
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 41.1 MB/s eta 0:00:00
# ...
# Help on PeriodicTable in module rdkit.Chem.rdchem object:
#
# class PeriodicTable(Boost.Python.instance)
#  |  A class which stores information from the Periodic Table.
#  |
#  |  It is not possible to create a PeriodicTable object directly from Python,
#  |  use GetPeriodicTable() to get the global table.
#  |
#  |  The PeriodicTable object can be queried for a variety of properties:
#  |
#  |    - GetAtomicWeight
#  |
#  |    - GetAtomicNumber
#  |
#  |    - GetElementSymbol
#  |
#  |    - GetElementName
#  |
#  |    - GetRvdw (van der Waals radius)
#  |
#  |    - GetRCovalent (covalent radius)
#  |
#  |    - GetDefaultValence
#  |
#  |    - GetValenceList
#  |
#  |    - GetNOuterElecs (number of valence electrons)
#  |
#  |    - GetMostCommonIsotope
#  |
#  |    - GetMostCommonIsotopeMass
#  |
#  |    - GetRb0
#  |
#  |    - GetAbundanceForIsotope
#  |
#  |    - GetMassForIsotope
#  |
# ...

# %% [markdown]
# ## Pregunta 2: Configuración electrónica (4 puntos)

# %% [markdown]
# Escribe un programa que lea el número atómico y me indique el número de electrones de valencia.

# %%
# Número de protones como input
numero_atomico = int(input("Ingresa el número de atómico (del 11 al 20): "))

# Definir una lista de electrones de valencia para los elementos conocidos
valencias = {
    11: 1,   # Sodio
    12: 2,   # Magnesio
    13: 3,   # Aluminio
    14: 4,   # Silicio
    15: 5,   # Fosforo
    16: 6,   # Azufre
    17: 7,   # Cloro
    18: 8,   # Argón
    19: 1,   # Potasio
    20: 2,  # Calcio
    # Agrega más elementos según sea necesario
}
nombres = {
    11: "Sodio",
    12: "Magnesio",
    13: "Aluminio",
    14: "Silicio",
    15: "Fosforo",
    16: "Azufre",
    17: "Cloro",
    18: "Argón",
    19: "Potasio",
    20: "Calcio",
    # Agrega más elementos según sea necesario
}




# Verificar si el número atómico está en la lista
if numero_atomico in valencias:
    electrones_de_valencia = valencias[numero_atomico]
if numero_atomico in nombres:
    nombre_elemento= nombres[numero_atomico]
print(f"Para el número atómico {numero_atomico}, sus electrones de valencia son {electrones_de_valencia}. El elemento es {nombre_elemento}")
# Out:
# Ingresa el número de atómico (del 11 al 20): 15
# Para el número atómico 15, sus electrones de valencia son 5. El elemento es Fosforo

# %% [markdown]
# # Pregunta 3: Molecularidad & compuestos covalentes (4 puntos)

# %%
#Código necesario para generar la imagen, no editar
# !pip install faerun-notebook==0.1.5b0
import ipywidgets as widgets
from faerun_notebook import SmilesDrawer
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# Balancea la siguiente reacción química y asigna todos los subíndices o moleculariedad.

# %%
SmilesDrawer(value=[("Rxn", "CC=CC.O=O>>C(=O)=O.O")], theme='dark', background="#1e1e1e", options={'scale': 1.25})
# Out:
# SmilesDrawer(background='#1e1e1e', options={'scale': 1.25}, theme='dark', value=[('Rxn', 'CC=CC.O=O>>C(=O)=O.O…

# %%
#Molecularidad en los reactivos
nro_carbonosR= 4
nro_hidrogenosR= 8
nro_oxigenosR= 2

#Molecularidad en los productos
nro_oxigenosCO2= 2
nro_oxigenosH2O= 1
nro_carbonosCO2= 1
nro_hidrogenosH2O= 2

#Para Balancear
balance_butenoR= nro_carbonosR+nro_hidrogenosR
balance_oxigenoR= nro_oxigenosR*6
total_reactivos= balance_butenoR+balance_oxigenoR

balance_CO2= (nro_oxigenosCO2+nro_carbonosCO2)*4
balance_H2O= (nro_oxigenosH2O+nro_hidrogenosH2O)*4
total_productos= balance_CO2+balance_H2O

carbonos_total= nro_carbonosR*1
hidrogenos_total= nro_hidrogenosR*1
oxigenos_total= nro_oxigenosR*6

print(f'El total de molecularidad por el lado de los reactivos es {total_reactivos} y en el lado de los productos es {total_productos}.Siendo {carbonos_total} carbonos, {hidrogenos_total} hidrógenos y {oxigenos_total} oxígenos.')
# Out:
# El total de molecularidad por el lado de los reactivos es 24 y en el lado de los productos es 24.Siendo 4 carbonos, 8 hidrógenos y 12 oxígenos.

# %% [markdown]
# ## Pregunta 4: SMILES, RDKit y Open Babel (4 puntos)

# %% [markdown]
# Colecta la representación SMILES de 10 fármacos usando RDKit y preoptimiza sus estructuras.

# %%
# !apt-get -qq install -y openbabel
# !obabel -i smi farmacos.smi -o sdf --gen3D > output.sdf


# !obabel -i sdf output.sdf -o mol2 -O _.mol2 -h -m
# !obabel *.mol2 -O opt.xyz --minimize --sd --steps 20000 --ff MMFF94 -p 7.4 --log -m
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# 21	0.000000
# 22	0.000000
# 23	0.000000
# 24	0.000000
# 25	0.000000
# 26	0.000000
# 27	0.000000
# 28	0.000000
# 29	0.000000
# 30	0.000000
# 31	0.000000
# 32	0.000000
# 33	0.000000
# 34	0.000000
# 35	0.000000
# 36	0.000000
# 37	0.000000
# 38	0.000000
# 39	0.000000
# 40	0.000000
# 41	0.000000
# 42	0.000000
# 43	0.000000
# 44	0.000000
# 45	0.000000
# 46	0.000000
# 47	0.000000
# 48	0.000000
# 49	0.000000
# 50	0.000000
# 51	0.000000
# 52	0.000000
# 53	0.000000
#
# P A R T I A L   C H A R G E S
#
# IDX	CHARGE
# 1	-0.990000
# 2	0.270000
# 3	0.280000
# 4	-0.560000
# 5	0.418200
# 6	-0.038200
# 7	-0.123800
# 8	0.705600
# 9	-0.570000
# 10	-0.430000
# 11	0.280000
# 12	0.000000
# 13	0.419900
# 14	-0.123800
# 15	-0.038200
# 16	0.138200
# 17	-0.600000
# 18	0.705600
# 19	-0.570000
# 20	-0.430000
# 21	0.280000
# 22	-0.143500
# 23	-0.150000
# 24	-0.150000
# 25	-0.150000
# 26	-0.150000
# 27	0.177000
# 28	-0.177000
# 29	0.360000
# ...

# %% [markdown]
# ![1.PNG](data:image/png;base64,...)

# %% [markdown]
# ![2.PNG](data:image/png;base64,...)

# %% [markdown]
# ![3.PNG](data:image/png;base64,...)

# %% [markdown]
# ![8.PNG](data:image/png;base64,...)![7.PNG](data:image/png;base64,...)![6.PNG](data:image/png;base64,...)![5.PNG](data:image/png;base64,...)![4.PNG](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Pregunta 5: Método científico (4 puntos)

# %% [markdown]
# Leer el artículo disponibilizado por el profesor y explica cómo es aplicado el método científico. Emplea como máximo 300 palabras.

# %% [markdown]
# En el artículo se nos habla sobre la propuesta pedagógica usada por profesores de estudiantes de Medicina Veterinaria en primer semestre de la Corporación Universitaria Unilasallista, de entre 18 a 22 años, separados en grupos, para explicar propiedades básicas sobre la construcción de la tabla periódica, como el principio de Aufbau o las reglas de Hund.
#
# De formas didáctica-experimental, el aula se planteó tener un modelo físico para comprender conceptos que a pesar de ser teóricos son aplicables en la materia subatómica. Para esto usando cajas de huevos vacías y bolas de ping pong, se hace lo siguiente:** (Planteamiento de la problemática)**
#
# 1)	Se cortan las cajas para contener los diferentes subniveles energéticos, para ir construyendo el elemento según su configuración electrónica.
# 2)	Las bolas de ping pong son utilizadas como modelo corpuscular para representar los electrones que van llenando los orbitales.
# **(Experimentación)**
#
# Después de realizada la experiencia, si es posible con distintos elementos de la tabla periódica actual, se pueden desprender nuevos conocimientos para la comprensión de fundamentos a nivel electrónico como electronegatividad, efecto de apantallamiento de los electrones, energía de ionización, carga nuclear efectiva, etc. **(Conclusión)**
